# %%
import spotipy
import pandas as pd
import numpy as np
import json
import os
import random
from plotly import express as px
from sklearn.cluster import KMeans
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt
from mpl_toolkits import mplot3d as m3d
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv
from IPython.display import IFrame
import config

# %%
os.getcwd()
# Out:
# 'c:\\Users\\romai\\Documents\\Source\\DAFT_0410\\module_2\\Project_Week_6'

# %%
#load_dotenv('.env')
#load_dotenv('.env')
c_id = config.c_id
c_se = config.c_se

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=c_id, client_secret=c_se))

# %% [markdown]
# ## Start

# %%
genres = ['A Cappella','Acid House','Acid Jazz','Acid Techno','Acoustic Blues','Acoustic Pop','African Percussion','Afrobeat','Alternative Country','Albuquerque Indie','Alternative Americana','Alternative Country','Alternative Dance','Alternative Emo','Alternative Hardcore','Alternative Hip Hop','Alternative Metal','Alternative Metalcore','Alternative New Age','Alternative Pop','Alternative Pop Rock','Alternative R&b','Alternative Rock']
genres = genres + ['Baroque','Bebop','Black Metal','Blues','Blues-rock','Bossa Nova','Brazilian Gospel','Breakbeat','Britpop']
genres = genres + ['Cabaret','Cajun','Calypso','Candy Pop','Capoeira','Cello','Celtic','Celtic Rock','Chanson','Chill Groove','Chill Lounge','Choral','Christmas']
genres = genres + ['Classic Afrobeat','Classic Belgian Pop','Classic Chinese Pop','Classic Colombian Pop','Classic Czech Pop','Classic Danish Pop','Classic Dutch Pop','Classic Eurovision','Classic Finnish Pop','Classic Finnish Rock','Classic French Pop','Classic Funk Rock','Classic Garage Rock','Classic Italian Pop','Classic Norwegian Pop','Classic Peruvian Pop','Classic Polish Pop','Classic Psychedelic Rock','Classic Rock','Classic Russian Pop','Classic Russian Rock','Classic Schlager','Classic Soundtrack','Classic Swedish Pop','Classic Turkish Pop','Classic Venezuelan Pop','Classical','Classical Christmas','Classical Flute','Classical Guitar','Classical Organ','Classical Performance','Classical Period','Classical Piano']
genres = genres + ['Comedy','Concert Piano','Country Blues','Country Christmas','Country Dawn','Country Gospel','Country Road','Country Rock']
genres = genres + ['Dance Pop','Dance Rock','Dance-punk','Digital Hardcore','Dirty South Rap','Dirty Texas Rap','Disco','Dubstep']
genres = genres + ['Electric Blues','Electro','Electro Dub','Electro House','Electro Jazz','Electro Latino','Electro Swing','Electro Trash','Electro-industrial','Eurovision']
genres = genres + ['Experimental','Experimental Dubstep','Experimental Psych','Experimental Rock']
genres = genres + ['Flamenco','Folk','Folk Christmas','Folk Metal','Folk Punk','Folk Rock','Folk-pop','Folk-prog','Folklore Argentino','Folkmusik','Free Jazz','Freestyle','French Folk','French Folk Pop','French Hip Hop','French Indie Pop','French Movie Tunes','French Pop','French Punk','French Reggae','French Rock']
genres = genres + ['Funk','Funk Carioca','Funk Metal','Funk Rock','Gangster Rap','Garage Pop','Garage Punk','Garage Punk Blues','Garage Rock','Gangster Rap','Garage Pop','Garage Punk','Garage Punk Blues','Garage Rock']
genres = genres + ['Groove Metal','Grunge','Grunge Pop','Gypsy Jazz','Hard Alternative','Hard Bop','Hard Glam','Hard House','Hard Rock','Hard Stoner Rock','Hard Trance','Hardcore','Hardcore Breaks','Hardcore Hip Hop','Hardcore Punk','Hardcore Techno']
genres = genres + ['Harmonica Blues','Heavy Alternative','Hip Hop','Hip Pop','Indie Dream Pop','Indie Emo','Indie Emo Rock','Indie Folk','Indie Fuzzpop','Indie Pop','Indie Pop Rock','Indie Post-punk','Indie Psych-pop','Indie R&b','Indie Rock','Indie Shoegaze','Indie Singer-songwriter']
genres = genres + ['Indorock','Industrial','Industrial Metal','Industrial Rock','Instrumental Post Rock','Jazz','Jazz Bass','Jazz Blues','Jazz Brass','Jazz Christmas','Jazz Funk','Jazz Fusion','Jazz Metal','Jazz Orchestra','Jazz Trio']
genres = genres + ['K-hop','Latin','Latin Alternative','Latin Christian','Latin Christmas','Latin Electronica','Latin Hip Hop','Latin Jazz','Latin Metal','Latin Pop']
genres = genres + ['Lounge','Lounge House','Mambo','Mariachi','Mashup','Medieval','Metal','Military Band','Minimal','Minimal Dub','Minimal Dubstep','Minimal Melodic Techno','Minimal Tech House','Minimal Techno','Minimal Wave']
genres = genres + ['Modern Blues','Modern Classical','Modern Country Rock','Modern Downshift','Modern Free Jazz','Modern Performance','Modern Southern Rock','Motown','Musique Pour Enfants']
genres = genres + ['Neo Classical Metal','Neo Honky Tonk','Neo Mellow','Neo Metal','Neo Soul','Neo Soul-jazz','Neo-industrial Rock','Neo-pagan','Neo-progressive','Neo-psychedelic','Neo-rockabilly','Neo-singer-songwriter','Neo-synthpop','Neo-trad Metal','Neo-traditional Country','Neoclassical','Neofolk']
genres = genres + ['New Age','New Beat','New Wave','Old School Hip Hop','Opera','Orchestral','Piano Rock','Pop','Pop Christmas','Pop Emo','Pop House','Pop Punk','Pop Rap','Pop Rock']
genres = genres + ['Progressive Alternative','Progressive Bluegrass','Progressive Electro House','Progressive House','Progressive Metal','Progressive Psytrance','Progressive Rock','Progressive Trance','Progressive Trance House','Progressive Uplifting Trance']
genres = genres + ['Psychedelic Blues-rock','Psychedelic Rock','Psychedelic Trance','Punk','Punk Blues','Punk Christmas','Punk Ska','R&b','Ragga Jungle','Rap','Rap Metal','Rap Metalcore','Rap Rock','Raw Black Metal']
genres = genres + ['Reggae','Reggae Fusion','Reggae Rock','Reggaeton','Rock','Rock Catala','Rock En Espanol','Rock Gaucho','Rock Noise','Rock Steady','Rock-and-roll','Rockabilly']
genres = genres + ['Rumba','Salsa','Samba','Ska','Ska Punk','Ska Revival','Smooth Jazz','Soul','Soul Blues','Soul Christmas','Soul Flow','Soul Jazz','Soundtrack']
genres = genres + ['Space Rock','Surf Music','Swamp Blues','Swamp Pop','Tango','Tech House','Techno','Texas Blues','Traditional Blues','Traditional British Folk','Traditional Country','Traditional Folk','Traditional Funk','Traditional Irish Fol','Traditional Reggae','Traditional Rockabilly','Traditional Scottish Folk','Traditional Ska','Traditional Soul','Traditional Swing','Trance']
genres = genres + ['Trash Rock','Tribal House','Trip Hop','Violin','Zouk','Zydeco']

# %%
len(genres)
# Out:
# 333

# %%
print(genres)
# Out:
# ['A Cappella', 'Acid House', 'Acid Jazz', 'Acid Techno', 'Acoustic Blues', 'Acoustic Pop', 'African Percussion', 'Afrobeat', 'Alternative Country', 'Albuquerque Indie', 'Alternative Americana', 'Alternative Country', 'Alternative Dance', 'Alternative Emo', 'Alternative Hardcore', 'Alternative Hip Hop', 'Alternative Metal', 'Alternative Metalcore', 'Alternative New Age', 'Alternative Pop', 'Alternative Pop Rock', 'Alternative R&b', 'Alternative Rock', 'Baroque', 'Bebop', 'Black Metal', 'Blues', 'Blues-rock', 'Bossa Nova', 'Brazilian Gospel', 'Breakbeat', 'Britpop', 'Cabaret', 'Cajun', 'Calypso', 'Candy Pop', 'Capoeira', 'Cello', 'Celtic', 'Celtic Rock', 'Chanson', 'Chill Groove', 'Chill Lounge', 'Choral', 'Christmas', 'Classic Afrobeat', 'Classic Belgian Pop', 'Classic Chinese Pop', 'Classic Colombian Pop', 'Classic Czech Pop', 'Classic Danish Pop', 'Classic Dutch Pop', 'Classic Eurovision', 'Classic Finnish Pop', 'Classic Finnish Rock', 'Classic French Pop', 'Classic Funk Rock', 'Classic Garage Rock', 'Classic Italian Pop', 'Classic Norwegian Pop', 'Classic Peruvian Pop', 'Classic Polish Pop', 'Classic Psychedelic Rock', 'Classic Rock', 'Classic Russian Pop', 'Classic Russian Rock', 'Classic Schlager', 'Classic Soundtrack', 'Classic Swedish Pop', 'Classic Turkish Pop', 'Classic Venezuelan Pop', 'Classical', 'Classical Christmas', 'Classical Flute', 'Classical Guitar', 'Classical Organ', 'Classical Performance', 'Classical Period', 'Classical Piano', 'Comedy', 'Concert Piano', 'Country Blues', 'Country Christmas', 'Country Dawn', 'Country Gospel', 'Country Road', 'Country Rock', 'Dance Pop', 'Dance Rock', 'Dance-punk', 'Digital Hardcore', 'Dirty South Rap', 'Dirty Texas Rap', 'Disco', 'Dubstep', 'Electric Blues', 'Electro', 'Electro Dub', 'Electro House', 'Electro Jazz', 'Electro Latino', 'Electro Swing', 'Electro Trash', 'Electro-industrial', 'Eurovision', 'Experimental', 'Experimental Dubstep', 'Experimental Psych', 'Experimental Rock', 'Flamenco', 'Folk', 'Folk Christmas', 'Folk Metal', 'Folk Punk', 'Folk Rock', 'Folk-pop', 'Folk-prog', 'Folklore Argentino', 'Folkmusik', 'Free Jazz', 'Freestyle', 'French Folk', 'French Folk Pop', 'French Hip Hop', 'French Indie Pop', 'French Movie Tunes', 'French Pop', 'French Punk', 'French Reggae', 'French Rock', 'Funk', 'Funk Carioca', 'Funk Metal', 'Funk Rock', 'Gangster Rap', 'Garage Pop', 'Garage Punk', 'Garage Punk Blues', 'Garage Rock', 'Gangster Rap', 'Garage Pop', 'Garage Punk', 'Garage Punk Blues', 'Garage Rock', 'Groove Metal', 'Grunge', 'Grunge Pop', 'Gypsy Jazz', 'Hard Alternative', 'Hard Bop', 'Hard Glam', 'Hard House', 'Hard Rock', 'Hard Stoner Rock', 'Hard Trance', 'Hardcore', 'Hardcore Breaks', 'Hardcore Hip Hop', 'Hardcore Punk', 'Hardcore Techno', 'Harmonica Blues', 'Heavy Alternative', 'Hip Hop', 'Hip Pop', 'Indie Dream Pop', 'Indie Emo', 'Indie Emo Rock', 'Indie Folk', 'Indie Fuzzpop', 'Indie Pop', 'Indie Pop Rock', 'Indie Post-punk', 'Indie Psych-pop', 'Indie R&b', 'Indie Rock', 'Indie Shoegaze', 'Indie Singer-songwriter', 'Indorock', 'Industrial', 'Industrial Metal', 'Industrial Rock', 'Instrumental Post Rock', 'Jazz', 'Jazz Bass', 'Jazz Blues', 'Jazz Brass', 'Jazz Christmas', 'Jazz Funk', 'Jazz Fusion', 'Jazz Metal', 'Jazz Orchestra', 'Jazz Trio', 'K-hop', 'Latin', 'Latin Alternative', 'Latin Christian', 'Latin Christmas', 'Latin Electronica', 'Latin Hip Hop', 'Latin Jazz', 'Latin Metal', 'Latin Pop', 'Lounge', 'Lounge House', 'Mambo', 'Mariachi', 'Mashup', 'Medieval', 'Metal', 'Military Band', 'Minimal', 'Minimal Dub', 'Minimal Dubstep', 'Minimal Melodic Techno', 'Minimal Tech House', 'Minimal Techno', 'Minimal Wave', 'Modern Blues', 'Modern Classical', 'Modern Country Rock', 'Modern Downshift', 'Modern Free Jazz', 'Modern Performance', 'Modern Southern Rock', 'Motown', 'Musique Pour Enfants', 'Neo Classical Metal', 'Neo Honky Tonk', 'Neo Mellow', 'Neo Metal', 'Neo Soul', 'Neo Soul-jazz', 'Neo-industrial Rock', 'Neo-pagan', 'Neo-progressive', 'Neo-psychedelic', 'Neo ...

# %%
genres_nocap = list(map(lambda x: x.lower(), genres))  
print(genres_nocap)
genre_nocap_dict = {genre: i for i, genre in enumerate(sorted(genres_nocap, key=lambda x: x.split()[-1]))}
# Out:
# ['a cappella', 'acid house', 'acid jazz', 'acid techno', 'acoustic blues', 'acoustic pop', 'african percussion', 'afrobeat', 'alternative country', 'albuquerque indie', 'alternative americana', 'alternative country', 'alternative dance', 'alternative emo', 'alternative hardcore', 'alternative hip hop', 'alternative metal', 'alternative metalcore', 'alternative new age', 'alternative pop', 'alternative pop rock', 'alternative r&b', 'alternative rock', 'baroque', 'bebop', 'black metal', 'blues', 'blues-rock', 'bossa nova', 'brazilian gospel', 'breakbeat', 'britpop', 'cabaret', 'cajun', 'calypso', 'candy pop', 'capoeira', 'cello', 'celtic', 'celtic rock', 'chanson', 'chill groove', 'chill lounge', 'choral', 'christmas', 'classic afrobeat', 'classic belgian pop', 'classic chinese pop', 'classic colombian pop', 'classic czech pop', 'classic danish pop', 'classic dutch pop', 'classic eurovision', 'classic finnish pop', 'classic finnish rock', 'classic french pop', 'classic funk rock', 'classic garage rock', 'classic italian pop', 'classic norwegian pop', 'classic peruvian pop', 'classic polish pop', 'classic psychedelic rock', 'classic rock', 'classic russian pop', 'classic russian rock', 'classic schlager', 'classic soundtrack', 'classic swedish pop', 'classic turkish pop', 'classic venezuelan pop', 'classical', 'classical christmas', 'classical flute', 'classical guitar', 'classical organ', 'classical performance', 'classical period', 'classical piano', 'comedy', 'concert piano', 'country blues', 'country christmas', 'country dawn', 'country gospel', 'country road', 'country rock', 'dance pop', 'dance rock', 'dance-punk', 'digital hardcore', 'dirty south rap', 'dirty texas rap', 'disco', 'dubstep', 'electric blues', 'electro', 'electro dub', 'electro house', 'electro jazz', 'electro latino', 'electro swing', 'electro trash', 'electro-industrial', 'eurovision', 'experimental', 'experimental dubstep', 'experimental psych', 'experimental rock', 'flamenco', 'folk', 'folk christmas', 'folk metal', 'folk punk', 'folk rock', 'folk-pop', 'folk-prog', 'folklore argentino', 'folkmusik', 'free jazz', 'freestyle', 'french folk', 'french folk pop', 'french hip hop', 'french indie pop', 'french movie tunes', 'french pop', 'french punk', 'french reggae', 'french rock', 'funk', 'funk carioca', 'funk metal', 'funk rock', 'gangster rap', 'garage pop', 'garage punk', 'garage punk blues', 'garage rock', 'gangster rap', 'garage pop', 'garage punk', 'garage punk blues', 'garage rock', 'groove metal', 'grunge', 'grunge pop', 'gypsy jazz', 'hard alternative', 'hard bop', 'hard glam', 'hard house', 'hard rock', 'hard stoner rock', 'hard trance', 'hardcore', 'hardcore breaks', 'hardcore hip hop', 'hardcore punk', 'hardcore techno', 'harmonica blues', 'heavy alternative', 'hip hop', 'hip pop', 'indie dream pop', 'indie emo', 'indie emo rock', 'indie folk', 'indie fuzzpop', 'indie pop', 'indie pop rock', 'indie post-punk', 'indie psych-pop', 'indie r&b', 'indie rock', 'indie shoegaze', 'indie singer-songwriter', 'indorock', 'industrial', 'industrial metal', 'industrial rock', 'instrumental post rock', 'jazz', 'jazz bass', 'jazz blues', 'jazz brass', 'jazz christmas', 'jazz funk', 'jazz fusion', 'jazz metal', 'jazz orchestra', 'jazz trio', 'k-hop', 'latin', 'latin alternative', 'latin christian', 'latin christmas', 'latin electronica', 'latin hip hop', 'latin jazz', 'latin metal', 'latin pop', 'lounge', 'lounge house', 'mambo', 'mariachi', 'mashup', 'medieval', 'metal', 'military band', 'minimal', 'minimal dub', 'minimal dubstep', 'minimal melodic techno', 'minimal tech house', 'minimal techno', 'minimal wave', 'modern blues', 'modern classical', 'modern country rock', 'modern downshift', 'modern free jazz', 'modern performance', 'modern southern rock', 'motown', 'musique pour enfants', 'neo classical metal', 'neo honky tonk', 'neo mellow', 'neo metal', 'neo soul', 'neo soul-jazz', 'neo-industrial rock', 'neo-pagan', 'neo-progressive', 'neo-psychedelic', 'neo ...

# %%
genre_dict = {genre: i for i, genre in enumerate(sorted(genres, key=lambda x: x.split()[-1]))}

# %%
genre_dict
# Out:
# {'Afrobeat': 0,
#  'Classic Afrobeat': 1,
#  'Alternative New Age': 2,
#  'New Age': 3,
#  'Hard Alternative': 4,
#  'Heavy Alternative': 5,
#  'Latin Alternative': 6,
#  'Progressive Alternative': 7,
#  'Alternative Americana': 8,
#  'Folklore Argentino': 9,
#  'Military Band': 10,
#  'Baroque': 11,
#  'Jazz Bass': 12,
#  'New Beat': 13,
#  'Bebop': 14,
#  'Progressive Bluegrass': 15,
#  'Acoustic Blues': 16,
#  'Blues': 17,
#  'Country Blues': 18,
#  'Electric Blues': 19,
#  'Garage Punk Blues': 21,
#  'Harmonica Blues': 22,
#  'Jazz Blues': 23,
#  'Modern Blues': 24,
#  'Punk Blues': 25,
#  'Soul Blues': 26,
#  'Swamp Blues': 27,
#  'Texas Blues': 28,
#  'Traditional Blues': 29,
#  'Blues-rock': 30,
#  'Psychedelic Blues-rock': 31,
#  'Hard Bop': 32,
#  'Jazz Brass': 33,
#  'Breakbeat': 34,
#  'Hardcore Breaks': 35,
#  'Britpop': 36,
#  'Cabaret': 37,
#  'Cajun': 38,
#  'Calypso': 39,
#  'Capoeira': 40,
#  'A Cappella': 41,
#  'Funk Carioca': 42,
#  'Rock Catala': 43,
#  'Cello': 44,
#  'Celtic': 45,
#  'Chanson': 46,
#  'Choral': 47,
#  'Latin Christian': 48,
#  'Christmas': 49,
#  'Classical Christmas': 50,
#  'Country Christmas': 51,
#  'Folk Christmas': 52,
#  'Jazz Christmas': 53,
#  'Latin Christmas': 54,
#  'Pop Christmas': 55,
#  'Punk Christmas': 56,
#  'Soul Christmas': 57,
#  'Classical': 58,
#  'Modern Classical': 59,
#  'Comedy': 60,
#  'Alternative Country': 62,
#  'Neo-traditional Country': 63,
#  'Traditional Country': 64,
#  'Alternative Dance': 65,
#  'Dance-punk': 66,
#  'Country Dawn': 67,
#  'Disco': 68,
#  'Modern Downshift': 69,
#  'Electro Dub': 70,
#  'Minimal Dub': 71,
#  'Dubstep': 72,
#  'Experimental Dubstep': 73,
#  'Minimal Dubstep': 74,
#  'Electro': 75,
#  'Electro-industrial': 76,
#  'Latin Electronica': 77,
#  'Alternative Emo': 78,
#  'Indie Emo': 79,
#  'Pop Emo': 80,
#  'Musique Pour Enfants': 81,
#  'Rock En Espanol': 82,
#  'Classic Eurovision': 83,
#  'Eurovision': 84,
#  'Experimental': 85,
#  'Flamenco': 86,
#  'Soul Flow': 87,
#  'Classical Flute': 88,
#  'Traditional Irish Fol': 89,
#  'Folk': 90,
#  'French Folk': 91,
#  'Indie Folk': 92,
#  'Traditional British Folk': 93,
#  'Traditional Folk': 94,
#  'Traditional Scottish Folk': 95,
#  'Folk-pop': 96,
#  'Folk-prog': 97,
#  'Folkmusik': 98,
#  'Freestyle': 99,
#  'Funk': 100,
#  'Jazz Funk': 101,
#  'Traditional Funk': 102,
#  'Jazz Fusion': 103,
#  'Reggae Fusion': 104,
#  'Indie Fuzzpop': 105,
#  'Rock Gaucho': 106,
#  'Hard Glam': 107,
#  'Brazilian Gospel': 108,
#  'Country Gospel': 109,
#  'Chill Groove': 110,
#  'Grunge': 111,
#  'Classical Guitar': 112,
#  'Alternative Hardcore': 113,
#  'Digital Hardcore': 114,
#  'Hardcore': 115,
#  'Alternative Hip Hop': 116,
#  'French Hip Hop': 117,
#  'Hardcore Hip Hop': 118,
#  'Hip Hop': 119,
#  'Latin Hip Hop': 120,
#  'Old School Hip Hop': 121,
#  'Trip Hop': 122,
#  'Acid House': 123,
#  'Electro House': 124,
#  'Hard House': 125,
#  'Lounge House': 126,
#  'Minimal Tech House': 127,
#  'Pop House': 128,
#  'Progressive Electro House': 129,
#  'Progressive House': 130,
#  'Progressive Trance House': 131,
#  'Tech House': 132,
#  'Tribal House': 133,
#  'Albuquerque Indie': 134,
#  'Indorock': 135,
#  'Industrial': 136,
#  'Acid Jazz': 137,
#  'Electro Jazz': 138,
#  'Free Jazz': 139,
#  'Gypsy Jazz': 140,
#  'Jazz': 141,
#  'Latin Jazz': 142,
#  'Modern Free Jazz': 143,
#  'Smooth Jazz': 144,
#  'Soul Jazz': 145,
#  'Ragga Jungle': 146,
#  'K-hop': 147,
#  'Latin': 148,
#  'Electro Latino': 149,
#  'Chill Lounge': 150,
#  'Lounge': 151,
#  'Mambo': 152,
#  'Mariachi': 153,
#  'Mashup': 154,
#  'Medieval': 155,
#  'Neo Mellow': 156,
#  'Alternative Metal': 157,
#  'Black Metal': 158,
#  'Folk Metal': 159,
#  'Funk Metal': 160,
#  'Groove Metal': 161,
#  'Industrial Metal': 162,
#  'Jazz Metal': 163,
#  'Latin Metal': 164,
#  'Metal': 165,
#  'Neo Classical Metal': 166,
#  'Neo Metal': 167,
#  'Neo-trad Metal': 168,
#  'Progressive Metal': 169,
#  'Rap Metal': 170,
#  'Raw Black Metal': 171,
#  'Alternative Metalcore': 172,
#  'Rap Metalcore': 173,
#  'Minimal': 174,
#  'Motown': 175,
#  'Surf Music': 176,
#  'Neo-pagan': 177,
#  'Neo-progressive': 178,
#  'Neo-psychedelic': 179,
#  'Neo-rockabilly': 180,
#  'Neo-singer-songwriter': 181,
#  'Neo-synthpop': 182,
#  'Neoclassical': 183,
#  'Neofolk': 184,
#  'Rock Noise': 185,
#  'Bossa Nova': 186,
#  'Opera': 187,
#  'Jazz Orchestra': 188,
#  'Orchestral': 189,
#  'Classical Organ': 190,
#  'African Percussion': 191,
#  'Classical Performance': 192,
#  'Modern Performance': 193,
#  'Classical Period': 194,
#  'Classical Piano': 195,
#  'Concert Piano': 196,
#  'Acoustic Pop': 197,
#  'Alternative Pop': 198,
#  'Candy Pop': 199,
#  'Classic Belgian Pop': 200,
#  'Classic Chinese Pop': 201,
#  'Classic Colombian Pop': 202,
#  'Classic Czech Pop': 203,
#  'Classic Danish Pop': 204,
#  'Classic Dutch Pop': 205,
#  'Classic Finnish Pop': 206,
#  'Classic French Pop': 207,
#  'Classic Italian Pop': 208,
#  'Classic Norwegian Pop': 209,
#  'Classic Peruvian Pop': 210,
#  'Classic Polish Pop': 211,
#  'Classic Russian Pop': 212,
#  'Classic Swedish Pop': 213,
#  'Classic Turkish Pop': 214,
#  'Classic Venezuelan Pop': 215,
#  'Dance Pop': 216,
#  'French Folk Pop': 217,
#  'French Indie Pop': 218,
#  'French Pop': 219,
#  'Garage Pop': 221,
#  'Grunge Pop': 222,
#  'Hip Pop': 223,
#  'Indie Dream Pop': 224,
#  'Indie Pop': 225,
#  'Latin Pop': 226,
#  'Pop': 227,
#  'Swamp Pop': 228,
#  'Indie Post-punk': 229,
#  'Experimental Psych': 230,
#  'Indie Psych-pop': 231,
#  'Progressive Psytrance': 232,
#  'Folk Punk': 233,
#  'French Punk': 234,
#  'Garage Punk': 236,
#  'Hardcore Punk': 237,
#  'Pop Punk': 238,
#  'Punk': 239,
#  'Ska Punk': 240,
#  'Alternative R&b': 241,
#  'Indie R&b': 242,
#  'R&b': 243,
#  'Dirty South Rap': 244,
#  'Dirty Texas Rap': 245,
#  'Gangster Rap': 247,
#  'Pop Rap': 248,
#  'Rap': 249,
#  'French Reggae': 250,
#  'Reggae': 251,
#  'Traditional Reggae': 252,
#  'Reggaeton': 253,
#  'Ska Revival': 254,
#  'Country Road': 255,
#  'Alternative Pop Rock': 256,
#  'Alternative Rock': 257,
#  'Celtic Rock': 258,
#  'Classic Finnish Rock': 259,
#  'Classic Funk Rock': 260,
#  'Classic Garage Rock': 261,
#  'Classic Psychedelic Rock': 262,
#  'Classic Rock': 263,
#  'Classic Russian Rock': 264,
#  'Country Rock': 265,
#  'Dance Rock': 266,
#  'Experimental Rock': 267,
#  'Folk Rock': 268,
#  'French Rock': 269,
#  'Funk Rock': 270,
#  'Garage Rock': 272,
#  'Hard Rock': 273,
#  'Hard Stoner Rock': 274,
#  'Indie Emo Rock': 275,
#  'Indie Pop Rock': 276,
#  'Indie Rock': 277,
#  'Industrial Rock': 278,
#  'Instrumental Post Rock': 279,
#  'Modern Country Rock': 280,
#  'Modern Southern Rock': 281,
#  'Neo-industrial Rock': 282,
#  'Piano Rock': 283,
#  'Pop Rock': 284,
#  'Progressive Rock': 285,
#  'Psychedelic Rock': 286,
#  'Rap Rock': 287,
#  'Reggae Rock': 288,
#  'Rock': 289,
#  'Space Rock': 290,
#  'Trash Rock': 291,
#  'Rock-and-roll': 292,
#  'Rockabilly': 293,
#  'Traditional Rockabilly': 294,
#  'Rumba': 295,
#  'Salsa': 296,
#  'Samba': 297,
#  'Classic Schlager': 298,
#  'Indie Shoegaze': 299,
#  'Indie Singer-songwriter': 300,
#  'Punk Ska': 301,
#  'Ska': 302,
#  'Traditional Ska': 303,
#  'Neo Soul': 304,
#  'Soul': 305,
#  'Traditional Soul': 306,
#  'Neo Soul-jazz': 307,
#  'Classic Soundtrack': 308,
#  'Soundtrack': 309,
#  'Rock Steady': 310,
#  'Electro Swing': 311,
#  'Traditional Swing': 312,
#  'Tango': 313,
#  'Acid Techno': 314,
#  'Hardcore Techno': 315,
#  'Minimal Melodic Techno': 316,
#  'Minimal Techno': 317,
#  'Techno': 318,
#  'Neo Honky Tonk': 319,
#  'Hard Trance': 320,
#  'Progressive Trance': 321,
#  'Progressive Uplifting Trance': 322,
#  'Psychedelic Trance': 323,
#  'Trance': 324,
#  'Electro Trash': 325,
#  'Jazz Trio': 326,
#  'French Movie Tunes': 327,
#  'Violin': 328,
#  'Minimal Wave': 329,
#  'New Wave': 330,
#  'Zouk': 331,
#  'Zydeco': 332}

# %% [markdown]
# # Get Traks & Features

# %%
start = 0
Limit=10
maxi = 49
Compteur = 0
CptGenre=0
Header=True
CptGenreTot = len(genres)
for genre in genres:
    Track_ids = []
    Tracks = []
    #Get track list
    for i in range(start,maxi,50):
        try:
            Results = sp.search(q='genre:"{}"'.format(genre), type='track',offset=i, limit=Limit)
            Tracks = Tracks + Results['tracks']['items']
        except spotipy.SpotifyException as e:
            print(e.msg)

    Track_ids = Track_ids + [Track['id'] for Track in Tracks]
    CptGenre += 1
    print(CptGenre,'|',CptGenreTot,' Len Tracks for ',genre,': ',len(Tracks))
    
    try:
        if len(Tracks) > 0:
            #Get audio_features
            list_of_audio_features=[]
            for item in range(0,len(Tracks)):
            #for item in range(0,10):
                MyDic = {}
                MyDic= '{ "item" : ' + str(Compteur) + ',"genre" : "' + genre + '" , "name" : "' + Tracks[item]['name'].replace('"','')  +  '" ,"artist" : "' + Tracks[item]['artists'][0]['name'].replace('"','') + '"}'
                #print(MyDic)
                Compteur += 1
                MyDic = json.loads(MyDic)
                try:
                    MyDic.update(sp.audio_features(Tracks[item]["id"])[0])
                    #print(MyDic)
                    list_of_audio_features.append(MyDic)
                except spotipy.SpotifyException as e:
                    print(e.msg)
            print('Get audio_features for ',genre,' : ', item + 1, ' Total : ',Compteur) 

            #save to file
            df=pd.DataFrame(list_of_audio_features)    
            df=df[["item","genre","id","name","artist","danceability","energy","key","mode","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo","duration_ms"]]
            #append to csv
            df.to_csv('audio_features.csv',mode='a',index=False, header=Header)
            Header = False
    except Exception as e:
        print(repr(e))

print("\n\n\nDone")
# Out:
# 1 | 333  Len Tracks for  A Cappella :  10
# Get audio_features for  A Cappella  :  10  Total :  10
# 2 | 333  Len Tracks for  Acid House :  10
# Get audio_features for  Acid House  :  10  Total :  20
# 3 | 333  Len Tracks for  Acid Jazz :  10
# Get audio_features for  Acid Jazz  :  10  Total :  30
# 4 | 333  Len Tracks for  Acid Techno :  10
# Get audio_features for  Acid Techno  :  10  Total :  40
# 5 | 333  Len Tracks for  Acoustic Blues :  10
# Get audio_features for  Acoustic Blues  :  10  Total :  50
# 6 | 333  Len Tracks for  Acoustic Pop :  10
# Get audio_features for  Acoustic Pop  :  10  Total :  60
# 7 | 333  Len Tracks for  African Percussion :  10
# Get audio_features for  African Percussion  :  10  Total :  70
# 8 | 333  Len Tracks for  Afrobeat :  10
# Get audio_features for  Afrobeat  :  10  Total :  80
# 9 | 333  Len Tracks for  Alternative Country :  10
# Get audio_features for  Alternative Country  :  10  Total :  90
# 10 | 333  Len Tracks for  Albuquerque Indie :  10
# Get audio_features for  Albuquerque Indie  :  10  Total :  100
# 11 | 333  Len Tracks for  Alternative Americana :  10
# Get audio_features for  Alternative Americana  :  10  Total :  110
# 12 | 333  Len Tracks for  Alternative Country :  10
# Get audio_features for  Alternative Country  :  10  Total :  120
# 13 | 333  Len Tracks for  Alternative Dance :  10
# Get audio_features for  Alternative Dance  :  10  Total :  130
# 14 | 333  Len Tracks for  Alternative Emo :  10
# Get audio_features for  Alternative Emo  :  10  Total :  140
# 15 | 333  Len Tracks for  Alternative Hardcore :  10
# Get audio_features for  Alternative Hardcore  :  10  Total :  150
# 16 | 333  Len Tracks for  Alternative Hip Hop :  10
# Get audio_features for  Alternative Hip Hop  :  10  Total :  160
# 17 | 333  Len Tracks for  Alternative Metal :  10
# Get audio_features for  Alternative Metal  :  10  Total :  170
# 18 | 333  Len Tracks for  Alternative Metalcore :  10
# Get audio_features for  Alternative Metalcore  :  10  Total :  180
# 19 | 333  Len Tracks for  Alternative New Age :  0
# 20 | 333  Len Tracks for  Alternative Pop :  10
# Get audio_features for  Alternative Pop  :  10  Total :  190
# 21 | 333  Len Tracks for  Alternative Pop Rock :  10
# Get audio_features for  Alternative Pop Rock  :  10  Total :  200
# 22 | 333  Len Tracks for  Alternative R&b :  10
# Get audio_features for  Alternative R&b  :  10  Total :  210
# 23 | 333  Len Tracks for  Alternative Rock :  10
# Get audio_features for  Alternative Rock  :  10  Total :  220
# 24 | 333  Len Tracks for  Baroque :  10
# Get audio_features for  Baroque  :  10  Total :  230
# 25 | 333  Len Tracks for  Bebop :  10
# Get audio_features for  Bebop  :  10  Total :  240
# 26 | 333  Len Tracks for  Black Metal :  10
# Get audio_features for  Black Metal  :  10  Total :  250
# 27 | 333  Len Tracks for  Blues :  10
# Get audio_features for  Blues  :  10  Total :  260
# 28 | 333  Len Tracks for  Blues-rock :  10
# Get audio_features for  Blues-rock  :  10  Total :  270
# 29 | 333  Len Tracks for  Bossa Nova :  10
# Get audio_features for  Bossa Nova  :  10  Total :  280
# 30 | 333  Len Tracks for  Brazilian Gospel :  10
# Get audio_features for  Brazilian Gospel  :  10  Total :  290
# 31 | 333  Len Tracks for  Breakbeat :  10
# Get audio_features for  Breakbeat  :  10  Total :  300
# 32 | 333  Len Tracks for  Britpop :  10
# Get audio_features for  Britpop  :  10  Total :  310
# 33 | 333  Len Tracks for  Cabaret :  10
# Get audio_features for  Cabaret  :  10  Total :  320
# 34 | 333  Len Tracks for  Cajun :  10
# Get audio_features for  Cajun  :  10  Total :  330
# 35 | 333  Len Tracks for  Calypso :  10
# Get audio_features for  Calypso  :  10  Total :  340
# 36 | 333  Len Tracks for  Candy Pop :  10
# Get audio_features for  Candy Pop  :  10  Total :  350
# 37 | 333  Len Tracks for  Capoeira :  10
# Get audio_features for  Capoeira  :  10  Total :  360
# 38 | 333  Len Tracks for  Cello :  10
# Get audio_features for  Cello  :  10  Total :  370
# 39 | 333  Len Tracks for  Celtic :  10
# Get audio_features for  Celtic  :  10  Total :  380
# 40 | 333  Len Tracks for  Celtic Rock :  10
# Get audio_features for  Celtic Rock  :  10  Total :  390
# 41 | 333  Len Tracks for  Chanson :  10
# Get audio_features for  Chanson  :  10  Total :  400
# 42 | 333  Len Tracks for  Chill Groove :  10
# Get audio_features for  Chill Groove  :  10  Total :  410
# 43 | 333  Len Tracks for  Chill Lounge :  10
# Get audio_features for  Chill Lounge  :  10  Total :  420
# 44 | 333  Len Tracks for  Choral :  10
# Get audio_features for  Choral  :  10  Total :  430
# 45 | 333  Len Tracks for  Christmas :  10
# Get audio_features for  Christmas  :  10  Total :  440
# 46 | 333  Len Tracks for  Classic Afrobeat :  10
# Get audio_features for  Classic Afrobeat  :  10  Total :  450
# 47 | 333  Len Tracks for  Classic Belgian Pop :  10
# Get audio_features for  Classic Belgian Pop  :  10  Total :  460
# 48 | 333  Len Tracks for  Classic Chinese Pop :  0
# 49 | 333  Len Tracks for  Classic Colombian Pop :  10
# Get audio_features for  Classic Colombian Pop  :  10  Total :  470
# 50 | 333  Len Tracks for  Classic Czech Pop :  10
# Get audio_features for  Classic Czech Pop  :  10  Total :  480
# 51 | 333  Len Tracks for  Classic Danish Pop :  10
# Get audio_features for  Classic Danish Pop  :  10  Total :  490
# 52 | 333  Len Tracks for  Classic Dutch Pop :  10
# Get audio_features for  Classic Dutch Pop  :  10  Total :  500
# 53 | 333  Len Tracks for  Classic Eurovision :  0
# 54 | 333  Len Tracks for  Classic Finnish Pop :  10
# Get audio_features for  Classic Finnish Pop  :  10  Total :  510
# 55 | 333  Len Tracks for  Classic Finnish Rock :  10
# Get audio_features for  Classic Finnish Rock  :  10  Total :  520
# 56 | 333  Len Tracks for  Classic French Pop :  10
# Get audio_features for  Classic French Pop  :  10  Total :  530
# 57 | 333  Len Tracks for  Classic Funk Rock :  0
# 58 | 333  Len Tracks for  Classic Garage Rock :  10
# Get audio_features for  Classic Garage Rock  :  10  Total :  540
# 59 | 333  Len Tracks for  Classic Italian Pop :  10
# Get audio_features for  Classic Italian Pop  :  10  Total :  550
# 60 | 333  Len Tracks for  Classic Norwegian Pop :  10
# Get audio_features for  Classic Norwegian Pop  :  10  Total :  560
# 61 | 333  Len Tracks for  Classic Peruvian Pop :  10
# Get audio_features for  Classic Peruvian Pop  :  10  Total :  570
# 62 | 333  Len Tracks for  Classic Polish Pop :  10
# Get audio_features for  Classic Polish Pop  :  10  Total :  580
# 63 | 333  Len Tracks for  Classic Psychedelic Rock :  10
# Get audio_features for  Classic Psychedelic Rock  :  10  Total :  590
# 64 | 333  Len Tracks for  Classic Rock :  10
# Get audio_features for  Classic Rock  :  10  Total :  600
# 65 | 333  Len Tracks for  Classic Russian Pop :  10
# Get audio_features for  Classic Russian Pop  :  10  Total :  610
# 66 | 333  Len Tracks for  Classic Russian Rock :  10
# Get audio_features for  Classic Russian Rock  :  10  Total :  620
# 67 | 333  Len Tracks for  Classic Schlager :  10
# Get audio_features for  Classic Schlager  :  10  Total :  630
# 68 | 333  Len Tracks for  Classic Soundtrack :  10
# Get audio_features for  Classic Soundtrack  :  10  Total :  640
# 69 | 333  Len Tracks for  Classic Swedish Pop :  10
# Get audio_features for  Classic Swedish Pop  :  10  Total :  650
# 70 | 333  Len Tracks for  Classic Turkish Pop :  10
# Get audio_features for  Classic Turkish Pop  :  10  Total :  660
# 71 | 333  Len Tracks for  Classic Venezuelan Pop :  10
# Get audio_features for  Classic Venezuelan Pop  :  10  Total :  670
# 72 | 333  Len Tracks for  Classical :  10
# Get audio_features for  Classical  :  10  Total :  680
# 73 | 333  Len Tracks for  Classical Christmas :  0
# 74 | 333  Len Tracks for  Classical Flute :  10
# Get audio_features for  Classical Flute  :  10  Total :  690
# 75 | 333  Len Tracks for  Classical Guitar :  10
# Get audio_features for  Classical Guitar  :  10  Total :  700
# 76 | 333  Len Tracks for  Classical Organ :  10
# Get audio_features for  Classical Organ  :  10  Total :  710
# 77 | 333  Len Tracks for  Classical Performance :  10
# Get audio_features for  Classical Performance  :  10  Total :  720
# 78 | 333  Len Tracks for  Classical Period :  0
# 79 | 333  Len Tracks for  Classical Piano :  10
# Get audio_features for  Classical Piano  :  10  Total :  730
# 80 | 333  Len Tracks for  Comedy :  10
# Get audio_features for  Comedy  :  10  Total :  740
# 81 | 333  Len Tracks for  Concert Piano :  0
# 82 | 333  Len Tracks for  Country Blues :  10
# Get audio_features for  Country Blues  :  10  Total :  750
# 83 | 333  Len Tracks for  Country Christmas :  0
# 84 | 333  Len Tracks for  Country Dawn :  10
# Get audio_features for  Country Dawn  :  10  Total :  760
# 85 | 333  Len Tracks for  Country Gospel :  10
# Get audio_features for  Country Gospel  :  10  Total :  770
# 86 | 333  Len Tracks for  Country Road :  10
# Get audio_features for  Country Road  :  10  Total :  780
# 87 | 333  Len Tracks for  Country Rock :  10
# Get audio_features for  Country Rock  :  10  Total :  790
# 88 | 333  Len Tracks for  Dance Pop :  10
# Get audio_features for  Dance Pop  :  10  Total :  800
# 89 | 333  Len Tracks for  Dance Rock :  10
# Get audio_features for  Dance Rock  :  10  Total :  810
# 90 | 333  Len Tracks for  Dance-punk :  10
# Get audio_features for  Dance-punk  :  10  Total :  820
# 91 | 333  Len Tracks for  Digital Hardcore :  10
# Get audio_features for  Digital Hardcore  :  10  Total :  830
# 92 | 333  Len Tracks for  Dirty South Rap :  10
# Get audio_features for  Dirty South Rap  :  10  Total :  840
# 93 | 333  Len Tracks for  Dirty Texas Rap :  10
# Get audio_features for  Dirty Texas Rap  :  10  Total :  850
# 94 | 333  Len Tracks for  Disco :  10
# Get audio_features for  Disco  :  10  Total :  860
# 95 | 333  Len Tracks for  Dubstep :  10
# Get audio_features for  Dubstep  :  10  Total :  870
# 96 | 333  Len Tracks for  Electric Blues :  10
# Get audio_features for  Electric Blues  :  10  Total :  880
# 97 | 333  Len Tracks for  Electro :  10
# Get audio_features for  Electro  :  10  Total :  890
# 98 | 333  Len Tracks for  Electro Dub :  10
# Get audio_features for  Electro Dub  :  10  Total :  900
# 99 | 333  Len Tracks for  Electro House :  10
# Get audio_features for  Electro House  :  10  Total :  910
# 100 | 333  Len Tracks for  Electro Jazz :  10
# Get audio_features for  Electro Jazz  :  10  Total :  920
# 101 | 333  Len Tracks for  Electro Latino :  10
# Get audio_features for  Electro Latino  :  10  Total :  930
# 102 | 333  Len Tracks for  Electro Swing :  10
# Get audio_features for  Electro Swing  :  10  Total :  940
# 103 | 333  Len Tracks for  Electro Trash :  10
# Get audio_features for  Electro Trash  :  10  Total :  950
# 104 | 333  Len Tracks for  Electro-industrial :  10
# Get audio_features for  Electro-industrial  :  10  Total :  960
# 105 | 333  Len Tracks for  Eurovision :  0
# 106 | 333  Len Tracks for  Experimental :  10
# Get audio_features for  Experimental  :  10  Total :  970
# 107 | 333  Len Tracks for  Experimental Dubstep :  10
# Get audio_features for  Experimental Dubstep  :  10  Total :  980
# 108 | 333  Len Tracks for  Experimental Psych :  10
# Get audio_features for  Experimental Psych  :  10  Total :  990
# 109 | 333  Len Tracks for  Experimental Rock :  10
# Get audio_features for  Experimental Rock  :  10  Total :  1000
# 110 | 333  Len Tracks for  Flamenco :  10
# Get audio_features for  Flamenco  :  10  Total :  1010
# 111 | 333  Len Tracks for  Folk :  10
# Get audio_features for  Folk  :  10  Total :  1020
# 112 | 333  Len Tracks for  Folk Christmas :  0
# 113 | 333  Len Tracks for  Folk Metal :  10
# Get audio_features for  Folk Metal  :  10  Total :  1030
# 114 | 333  Len Tracks for  Folk Punk :  10
# Get audio_features for  Folk Punk  :  10  Total :  1040
# 115 | 333  Len Tracks for  Folk Rock :  10
# Get audio_features for  Folk Rock  :  10  Total :  1050
# 116 | 333  Len Tracks for  Folk-pop :  10
# Get audio_features for  Folk-pop  :  10  Total :  1060
# 117 | 333  Len Tracks for  Folk-prog :  10
# Get audio_features for  Folk-prog  :  10  Total :  1070
# 118 | 333  Len Tracks for  Folklore Argentino :  10
# Get audio_features for  Folklore Argentino  :  10  Total :  1080
# 119 | 333  Len Tracks for  Folkmusik :  10
# Get audio_features for  Folkmusik  :  10  Total :  1090
# 120 | 333  Len Tracks for  Free Jazz :  10
# Get audio_features for  Free Jazz  :  10  Total :  1100
# 121 | 333  Len Tracks for  Freestyle :  10
# Get audio_features for  Freestyle  :  10  Total :  1110
# 122 | 333  Len Tracks for  French Folk :  10
# Get audio_features for  French Folk  :  10  Total :  1120
# 123 | 333  Len Tracks for  French Folk Pop :  10
# Get audio_features for  French Folk Pop  :  10  Total :  1130
# 124 | 333  Len Tracks for  French Hip Hop :  10
# Get audio_features for  French Hip Hop  :  10  Total :  1140
# 125 | 333  Len Tracks for  French Indie Pop :  10
# Get audio_features for  French Indie Pop  :  10  Total :  1150
# 126 | 333  Len Tracks for  French Movie Tunes :  10
# Get audio_features for  French Movie Tunes  :  10  Total :  1160
# 127 | 333  Len Tracks for  French Pop :  10
# Get audio_features for  French Pop  :  10  Total :  1170
# 128 | 333  Len Tracks for  French Punk :  10
# Get audio_features for  French Punk  :  10  Total :  1180
# 129 | 333  Len Tracks for  French Reggae :  10
# Get audio_features for  French Reggae  :  10  Total :  1190
# 130 | 333  Len Tracks for  French Rock :  10
# Get audio_features for  French Rock  :  10  Total :  1200
# 131 | 333  Len Tracks for  Funk :  10
# Get audio_features for  Funk  :  10  Total :  1210
# 132 | 333  Len Tracks for  Funk Carioca :  10
# Get audio_features for  Funk Carioca  :  10  Total :  1220
# 133 | 333  Len Tracks for  Funk Metal :  10
# Get audio_features for  Funk Metal  :  10  Total :  1230
# 134 | 333  Len Tracks for  Funk Rock :  10
# Get audio_features for  Funk Rock  :  10  Total :  1240
# 135 | 333  Len Tracks for  Gangster Rap :  10
# Get audio_features for  Gangster Rap  :  10  Total :  1250
# 136 | 333  Len Tracks for  Garage Pop :  10
# Get audio_features for  Garage Pop  :  10  Total :  1260
# 137 | 333  Len Tracks for  Garage Punk :  10
# Get audio_features for  Garage Punk  :  10  Total :  1270
# 138 | 333  Len Tracks for  Garage Punk Blues :  10
# Get audio_features for  Garage Punk Blues  :  10  Total :  1280
# 139 | 333  Len Tracks for  Garage Rock :  10
# Get audio_features for  Garage Rock  :  10  Total :  1290
# 140 | 333  Len Tracks for  Gangster Rap :  10
# Get audio_features for  Gangster Rap  :  10  Total :  1300
# 141 | 333  Len Tracks for  Garage Pop :  10
# Get audio_features for  Garage Pop  :  10  Total :  1310
# 142 | 333  Len Tracks for  Garage Punk :  10
# Get audio_features for  Garage Punk  :  10  Total :  1320
# 143 | 333  Len Tracks for  Garage Punk Blues :  10
# Get audio_features for  Garage Punk Blues  :  10  Total :  1330
# 144 | 333  Len Tracks for  Garage Rock :  10
# Get audio_features for  Garage Rock  :  10  Total :  1340
# 145 | 333  Len Tracks for  Groove Metal :  10
# Get audio_features for  Groove Metal  :  10  Total :  1350
# 146 | 333  Len Tracks for  Grunge :  10
# Get audio_features for  Grunge  :  10  Total :  1360
# 147 | 333  Len Tracks for  Grunge Pop :  10
# Get audio_features for  Grunge Pop  :  10  Total :  1370
# 148 | 333  Len Tracks for  Gypsy Jazz :  10
# Get audio_features for  Gypsy Jazz  :  10  Total :  1380
# 149 | 333  Len Tracks for  Hard Alternative :  10
# Get audio_features for  Hard Alternative  :  10  Total :  1390
# 150 | 333  Len Tracks for  Hard Bop :  10
# Get audio_features for  Hard Bop  :  10  Total :  1400
# 151 | 333  Len Tracks for  Hard Glam :  10
# Get audio_features for  Hard Glam  :  10  Total :  1410
# 152 | 333  Len Tracks for  Hard House :  10
# Get audio_features for  Hard House  :  10  Total :  1420
# 153 | 333  Len Tracks for  Hard Rock :  10
# Get audio_features for  Hard Rock  :  10  Total :  1430
# 154 | 333  Len Tracks for  Hard Stoner Rock :  10
# Get audio_features for  Hard Stoner Rock  :  10  Total :  1440
# 155 | 333  Len Tracks for  Hard Trance :  10
# Get audio_features for  Hard Trance  :  10  Total :  1450
# 156 | 333  Len Tracks for  Hardcore :  10
# Get audio_features for  Hardcore  :  10  Total :  1460
# 157 | 333  Len Tracks for  Hardcore Breaks :  10
# Get audio_features for  Hardcore Breaks  :  10  Total :  1470
# 158 | 333  Len Tracks for  Hardcore Hip Hop :  10
# Get audio_features for  Hardcore Hip Hop  :  10  Total :  1480
# 159 | 333  Len Tracks for  Hardcore Punk :  10
# Get audio_features for  Hardcore Punk  :  10  Total :  1490
# 160 | 333  Len Tracks for  Hardcore Techno :  10
# Get audio_features for  Hardcore Techno  :  10  Total :  1500
# 161 | 333  Len Tracks for  Harmonica Blues :  10
# Get audio_features for  Harmonica Blues  :  10  Total :  1510
# 162 | 333  Len Tracks for  Heavy Alternative :  10
# Get audio_features for  Heavy Alternative  :  10  Total :  1520
# 163 | 333  Len Tracks for  Hip Hop :  10
# Get audio_features for  Hip Hop  :  10  Total :  1530
# 164 | 333  Len Tracks for  Hip Pop :  10
# Get audio_features for  Hip Pop  :  10  Total :  1540
# 165 | 333  Len Tracks for  Indie Dream Pop :  10
# Get audio_features for  Indie Dream Pop  :  10  Total :  1550
# 166 | 333  Len Tracks for  Indie Emo :  10
# Get audio_features for  Indie Emo  :  10  Total :  1560
# 167 | 333  Len Tracks for  Indie Emo Rock :  10
# Get audio_features for  Indie Emo Rock  :  10  Total :  1570
# 168 | 333  Len Tracks for  Indie Folk :  10
# Get audio_features for  Indie Folk  :  10  Total :  1580
# 169 | 333  Len Tracks for  Indie Fuzzpop :  10
# Get audio_features for  Indie Fuzzpop  :  10  Total :  1590
# 170 | 333  Len Tracks for  Indie Pop :  10
# Get audio_features for  Indie Pop  :  10  Total :  1600
# 171 | 333  Len Tracks for  Indie Pop Rock :  10
# Get audio_features for  Indie Pop Rock  :  10  Total :  1610
# 172 | 333  Len Tracks for  Indie Post-punk :  0
# 173 | 333  Len Tracks for  Indie Psych-pop :  10
# Get audio_features for  Indie Psych-pop  :  10  Total :  1620
# 174 | 333  Len Tracks for  Indie R&b :  10
# Get audio_features for  Indie R&b  :  10  Total :  1630
# 175 | 333  Len Tracks for  Indie Rock :  10
# Get audio_features for  Indie Rock  :  10  Total :  1640
# 176 | 333  Len Tracks for  Indie Shoegaze :  10
# Get audio_features for  Indie Shoegaze  :  10  Total :  1650
# 177 | 333  Len Tracks for  Indie Singer-songwriter :  10
# Get audio_features for  Indie Singer-songwriter  :  10  Total :  1660
# 178 | 333  Len Tracks for  Indorock :  10
# Get audio_features for  Indorock  :  10  Total :  1670
# 179 | 333  Len Tracks for  Industrial :  10
# Get audio_features for  Industrial  :  10  Total :  1680
# 180 | 333  Len Tracks for  Industrial Metal :  10
# Get audio_features for  Industrial Metal  :  10  Total :  1690
# 181 | 333  Len Tracks for  Industrial Rock :  10
# Get audio_features for  Industrial Rock  :  10  Total :  1700
# 182 | 333  Len Tracks for  Instrumental Post Rock :  10
# Get audio_features for  Instrumental Post Rock  :  10  Total :  1710
# 183 | 333  Len Tracks for  Jazz :  10
# Get audio_features for  Jazz  :  10  Total :  1720
# 184 | 333  Len Tracks for  Jazz Bass :  10
# Get audio_features for  Jazz Bass  :  10  Total :  1730
# 185 | 333  Len Tracks for  Jazz Blues :  10
# Get audio_features for  Jazz Blues  :  10  Total :  1740
# 186 | 333  Len Tracks for  Jazz Brass :  10
# Get audio_features for  Jazz Brass  :  10  Total :  1750
# 187 | 333  Len Tracks for  Jazz Christmas :  0
# 188 | 333  Len Tracks for  Jazz Funk :  10
# Get audio_features for  Jazz Funk  :  10  Total :  1760
# 189 | 333  Len Tracks for  Jazz Fusion :  10
# Get audio_features for  Jazz Fusion  :  10  Total :  1770
# 190 | 333  Len Tracks for  Jazz Metal :  10
# Get audio_features for  Jazz Metal  :  10  Total :  1780
# 191 | 333  Len Tracks for  Jazz Orchestra :  10
# Get audio_features for  Jazz Orchestra  :  10  Total :  1790
# 192 | 333  Len Tracks for  Jazz Trio :  10
# Get audio_features for  Jazz Trio  :  10  Total :  1800
# 193 | 333  Len Tracks for  K-hop :  10
# Get audio_features for  K-hop  :  10  Total :  1810
# 194 | 333  Len Tracks for  Latin :  10
# Get audio_features for  Latin  :  10  Total :  1820
# 195 | 333  Len Tracks for  Latin Alternative :  10
# Get audio_features for  Latin Alternative  :  10  Total :  1830
# 196 | 333  Len Tracks for  Latin Christian :  10
# Get audio_features for  Latin Christian  :  10  Total :  1840
# 197 | 333  Len Tracks for  Latin Christmas :  0
# 198 | 333  Len Tracks for  Latin Electronica :  0
# 199 | 333  Len Tracks for  Latin Hip Hop :  10
# Get audio_features for  Latin Hip Hop  :  10  Total :  1850
# 200 | 333  Len Tracks for  Latin Jazz :  10
# Get audio_features for  Latin Jazz  :  10  Total :  1860
# 201 | 333  Len Tracks for  Latin Metal :  10
# Get audio_features for  Latin Metal  :  10  Total :  1870
# 202 | 333  Len Tracks for  Latin Pop :  10
# Get audio_features for  Latin Pop  :  10  Total :  1880
# 203 | 333  Len Tracks for  Lounge :  10
# Get audio_features for  Lounge  :  10  Total :  1890
# 204 | 333  Len Tracks for  Lounge House :  10
# Get audio_features for  Lounge House  :  10  Total :  1900
# 205 | 333  Len Tracks for  Mambo :  10
# Get audio_features for  Mambo  :  10  Total :  1910
# 206 | 333  Len Tracks for  Mariachi :  10
# Get audio_features for  Mariachi  :  10  Total :  1920
# 207 | 333  Len Tracks for  Mashup :  10
# Get audio_features for  Mashup  :  10  Total :  1930
# 208 | 333  Len Tracks for  Medieval :  10
# Get audio_features for  Medieval  :  10  Total :  1940
# 209 | 333  Len Tracks for  Metal :  10
# Get audio_features for  Metal  :  10  Total :  1950
# 210 | 333  Len Tracks for  Military Band :  10
# Get audio_features for  Military Band  :  10  Total :  1960
# 211 | 333  Len Tracks for  Minimal :  10
# Get audio_features for  Minimal  :  10  Total :  1970
# 212 | 333  Len Tracks for  Minimal Dub :  10
# Get audio_features for  Minimal Dub  :  10  Total :  1980
# 213 | 333  Len Tracks for  Minimal Dubstep :  10
# Get audio_features for  Minimal Dubstep  :  10  Total :  1990
# 214 | 333  Len Tracks for  Minimal Melodic Techno :  10
# Get audio_features for  Minimal Melodic Techno  :  10  Total :  2000
# 215 | 333  Len Tracks for  Minimal Tech House :  10
# Get audio_features for  Minimal Tech House  :  10  Total :  2010
# 216 | 333  Len Tracks for  Minimal Techno :  10
# Get audio_features for  Minimal Techno  :  10  Total :  2020
# 217 | 333  Len Tracks for  Minimal Wave :  10
# Get audio_features for  Minimal Wave  :  10  Total :  2030
# 218 | 333  Len Tracks for  Modern Blues :  10
# Get audio_features for  Modern Blues  :  10  Total :  2040
# 219 | 333  Len Tracks for  Modern Classical :  10
# Get audio_features for  Modern Classical  :  10  Total :  2050
# 220 | 333  Len Tracks for  Modern Country Rock :  10
# Get audio_features for  Modern Country Rock  :  10  Total :  2060
# 221 | 333  Len Tracks for  Modern Downshift :  10
# Get audio_features for  Modern Downshift  :  10  Total :  2070
# 222 | 333  Len Tracks for  Modern Free Jazz :  10
# Get audio_features for  Modern Free Jazz  :  10  Total :  2080
# 223 | 333  Len Tracks for  Modern Performance :  10
# Get audio_features for  Modern Performance  :  10  Total :  2090
# 224 | 333  Len Tracks for  Modern Southern Rock :  10
# Get audio_features for  Modern Southern Rock  :  10  Total :  2100
# 225 | 333  Len Tracks for  Motown :  10
# Get audio_features for  Motown  :  10  Total :  2110
# 226 | 333  Len Tracks for  Musique Pour Enfants :  10
# Get audio_features for  Musique Pour Enfants  :  10  Total :  2120
# 227 | 333  Len Tracks for  Neo Classical Metal :  10
# Get audio_features for  Neo Classical Metal  :  10  Total :  2130
# 228 | 333  Len Tracks for  Neo Honky Tonk :  10
# Get audio_features for  Neo Honky Tonk  :  10  Total :  2140
# 229 | 333  Len Tracks for  Neo Mellow :  10
# Get audio_features for  Neo Mellow  :  10  Total :  2150
# 230 | 333  Len Tracks for  Neo Metal :  10
# Get audio_features for  Neo Metal  :  10  Total :  2160
# 231 | 333  Len Tracks for  Neo Soul :  10
# Get audio_features for  Neo Soul  :  10  Total :  2170
# 232 | 333  Len Tracks for  Neo Soul-jazz :  10
# Get audio_features for  Neo Soul-jazz  :  10  Total :  2180
# 233 | 333  Len Tracks for  Neo-industrial Rock :  10
# Get audio_features for  Neo-industrial Rock  :  10  Total :  2190
# 234 | 333  Len Tracks for  Neo-pagan :  10
# Get audio_features for  Neo-pagan  :  10  Total :  2200
# 235 | 333  Len Tracks for  Neo-progressive :  10
# Get audio_features for  Neo-progressive  :  10  Total :  2210
# 236 | 333  Len Tracks for  Neo-psychedelic :  10
# Get audio_features for  Neo-psychedelic  :  10  Total :  2220
# 237 | 333  Len Tracks for  Neo-rockabilly :  10
# Get audio_features for  Neo-rockabilly  :  10  Total :  2230
# 238 | 333  Len Tracks for  Neo-singer-songwriter :  10
# Get audio_features for  Neo-singer-songwriter  :  10  Total :  2240
# 239 | 333  Len Tracks for  Neo-synthpop :  10
# Get audio_features for  Neo-synthpop  :  10  Total :  2250
# 240 | 333  Len Tracks for  Neo-trad Metal :  10
# Get audio_features for  Neo-trad Metal  :  10  Total :  2260
# 241 | 333  Len Tracks for  Neo-traditional Country :  10
# Get audio_features for  Neo-traditional Country  :  10  Total :  2270
# 242 | 333  Len Tracks for  Neoclassical :  10
# Get audio_features for  Neoclassical  :  10  Total :  2280
# 243 | 333  Len Tracks for  Neofolk :  10
# Get audio_features for  Neofolk  :  10  Total :  2290
# 244 | 333  Len Tracks for  New Age :  10
# Get audio_features for  New Age  :  10  Total :  2300
# 245 | 333  Len Tracks for  New Beat :  10
# Get audio_features for  New Beat  :  10  Total :  2310
# 246 | 333  Len Tracks for  New Wave :  10
# Get audio_features for  New Wave  :  10  Total :  2320
# 247 | 333  Len Tracks for  Old School Hip Hop :  10
# Get audio_features for  Old School Hip Hop  :  10  Total :  2330
# 248 | 333  Len Tracks for  Opera :  10
# Get audio_features for  Opera  :  10  Total :  2340
# 249 | 333  Len Tracks for  Orchestral :  10
# Get audio_features for  Orchestral  :  10  Total :  2350
# 250 | 333  Len Tracks for  Piano Rock :  10
# Get audio_features for  Piano Rock  :  10  Total :  2360
# 251 | 333  Len Tracks for  Pop :  10
# Get audio_features for  Pop  :  10  Total :  2370
# 252 | 333  Len Tracks for  Pop Christmas :  0
# 253 | 333  Len Tracks for  Pop Emo :  10
# Get audio_features for  Pop Emo  :  10  Total :  2380
# 254 | 333  Len Tracks for  Pop House :  10
# Get audio_features for  Pop House  :  10  Total :  2390
# 255 | 333  Len Tracks for  Pop Punk :  10
# Get audio_features for  Pop Punk  :  10  Total :  2400
# 256 | 333  Len Tracks for  Pop Rap :  10
# Get audio_features for  Pop Rap  :  10  Total :  2410
# 257 | 333  Len Tracks for  Pop Rock :  10
# Get audio_features for  Pop Rock  :  10  Total :  2420
# 258 | 333  Len Tracks for  Progressive Alternative :  10
# Get audio_features for  Progressive Alternative  :  10  Total :  2430
# 259 | 333  Len Tracks for  Progressive Bluegrass :  10
# Get audio_features for  Progressive Bluegrass  :  10  Total :  2440
# 260 | 333  Len Tracks for  Progressive Electro House :  10
# Get audio_features for  Progressive Electro House  :  10  Total :  2450
# 261 | 333  Len Tracks for  Progressive House :  10
# Get audio_features for  Progressive House  :  10  Total :  2460
# 262 | 333  Len Tracks for  Progressive Metal :  10
# Get audio_features for  Progressive Metal  :  10  Total :  2470
# 263 | 333  Len Tracks for  Progressive Psytrance :  10
# Get audio_features for  Progressive Psytrance  :  10  Total :  2480
# 264 | 333  Len Tracks for  Progressive Rock :  10
# Get audio_features for  Progressive Rock  :  10  Total :  2490
# 265 | 333  Len Tracks for  Progressive Trance :  10
# Get audio_features for  Progressive Trance  :  10  Total :  2500
# 266 | 333  Len Tracks for  Progressive Trance House :  10
# Get audio_features for  Progressive Trance House  :  10  Total :  2510
# 267 | 333  Len Tracks for  Progressive Uplifting Trance :  10
# Get audio_features for  Progressive Uplifting Trance  :  10  Total :  2520
# 268 | 333  Len Tracks for  Psychedelic Blues-rock :  10
# Get audio_features for  Psychedelic Blues-rock  :  10  Total :  2530
# 269 | 333  Len Tracks for  Psychedelic Rock :  10
# Get audio_features for  Psychedelic Rock  :  10  Total :  2540
# 270 | 333  Len Tracks for  Psychedelic Trance :  10
# Get audio_features for  Psychedelic Trance  :  10  Total :  2550
# 271 | 333  Len Tracks for  Punk :  10
# Get audio_features for  Punk  :  10  Total :  2560
# 272 | 333  Len Tracks for  Punk Blues :  10
# Get audio_features for  Punk Blues  :  10  Total :  2570
# 273 | 333  Len Tracks for  Punk Christmas :  0
# 274 | 333  Len Tracks for  Punk Ska :  10
# Get audio_features for  Punk Ska  :  10  Total :  2580
# 275 | 333  Len Tracks for  R&b :  10
# Get audio_features for  R&b  :  10  Total :  2590
# 276 | 333  Len Tracks for  Ragga Jungle :  10
# Get audio_features for  Ragga Jungle  :  10  Total :  2600
# 277 | 333  Len Tracks for  Rap :  10
# Get audio_features for  Rap  :  10  Total :  2610
# 278 | 333  Len Tracks for  Rap Metal :  10
# Get audio_features for  Rap Metal  :  10  Total :  2620
# 279 | 333  Len Tracks for  Rap Metalcore :  10
# Get audio_features for  Rap Metalcore  :  10  Total :  2630
# 280 | 333  Len Tracks for  Rap Rock :  10
# Get audio_features for  Rap Rock  :  10  Total :  2640
# 281 | 333  Len Tracks for  Raw Black Metal :  10
# Get audio_features for  Raw Black Metal  :  10  Total :  2650
# 282 | 333  Len Tracks for  Reggae :  10
# Get audio_features for  Reggae  :  10  Total :  2660
# 283 | 333  Len Tracks for  Reggae Fusion :  10
# Get audio_features for  Reggae Fusion  :  10  Total :  2670
# 284 | 333  Len Tracks for  Reggae Rock :  10
# Get audio_features for  Reggae Rock  :  10  Total :  2680
# 285 | 333  Len Tracks for  Reggaeton :  10
# Get audio_features for  Reggaeton  :  10  Total :  2690
# 286 | 333  Len Tracks for  Rock :  10
# Get audio_features for  Rock  :  10  Total :  2700
# 287 | 333  Len Tracks for  Rock Catala :  10
# Get audio_features for  Rock Catala  :  10  Total :  2710
# 288 | 333  Len Tracks for  Rock En Espanol :  10
# Get audio_features for  Rock En Espanol  :  10  Total :  2720
# 289 | 333  Len Tracks for  Rock Gaucho :  10
# Get audio_features for  Rock Gaucho  :  10  Total :  2730
# 290 | 333  Len Tracks for  Rock Noise :  10
# Get audio_features for  Rock Noise  :  10  Total :  2740
# 291 | 333  Len Tracks for  Rock Steady :  10
# Get audio_features for  Rock Steady  :  10  Total :  2750
# 292 | 333  Len Tracks for  Rock-and-roll :  10
# Get audio_features for  Rock-and-roll  :  10  Total :  2760
# 293 | 333  Len Tracks for  Rockabilly :  10
# Get audio_features for  Rockabilly  :  10  Total :  2770
# 294 | 333  Len Tracks for  Rumba :  10
# Get audio_features for  Rumba  :  10  Total :  2780
# 295 | 333  Len Tracks for  Salsa :  10
# Get audio_features for  Salsa  :  10  Total :  2790
# 296 | 333  Len Tracks for  Samba :  10
# Get audio_features for  Samba  :  10  Total :  2800
# 297 | 333  Len Tracks for  Ska :  10
# Get audio_features for  Ska  :  10  Total :  2810
# 298 | 333  Len Tracks for  Ska Punk :  10
# Get audio_features for  Ska Punk  :  10  Total :  2820
# 299 | 333  Len Tracks for  Ska Revival :  10
# Get audio_features for  Ska Revival  :  10  Total :  2830
# 300 | 333  Len Tracks for  Smooth Jazz :  10
# Get audio_features for  Smooth Jazz  :  10  Total :  2840
# 301 | 333  Len Tracks for  Soul :  10
# Get audio_features for  Soul  :  10  Total :  2850
# 302 | 333  Len Tracks for  Soul Blues :  10
# Get audio_features for  Soul Blues  :  10  Total :  2860
# 303 | 333  Len Tracks for  Soul Christmas :  0
# 304 | 333  Len Tracks for  Soul Flow :  10
# Get audio_features for  Soul Flow  :  10  Total :  2870
# 305 | 333  Len Tracks for  Soul Jazz :  10
# Get audio_features for  Soul Jazz  :  10  Total :  2880
# 306 | 333  Len Tracks for  Soundtrack :  10
# Get audio_features for  Soundtrack  :  10  Total :  2890
# 307 | 333  Len Tracks for  Space Rock :  10
# Get audio_features for  Space Rock  :  10  Total :  2900
# 308 | 333  Len Tracks for  Surf Music :  10
# Get audio_features for  Surf Music  :  10  Total :  2910
# 309 | 333  Len Tracks for  Swamp Blues :  10
# Get audio_features for  Swamp Blues  :  10  Total :  2920
# 310 | 333  Len Tracks for  Swamp Pop :  10
# Get audio_features for  Swamp Pop  :  10  Total :  2930
# 311 | 333  Len Tracks for  Tango :  10
# Get audio_features for  Tango  :  10  Total :  2940
# 312 | 333  Len Tracks for  Tech House :  10
# Get audio_features for  Tech House  :  10  Total :  2950
# 313 | 333  Len Tracks for  Techno :  10
# Get audio_features for  Techno  :  10  Total :  2960
# 314 | 333  Len Tracks for  Texas Blues :  10
# Get audio_features for  Texas Blues  :  10  Total :  2970
# 315 | 333  Len Tracks for  Traditional Blues :  10
# Get audio_features for  Traditional Blues  :  10  Total :  2980
# 316 | 333  Len Tracks for  Traditional British Folk :  10
# Get audio_features for  Traditional British Folk  :  10  Total :  2990
# 317 | 333  Len Tracks for  Traditional Country :  10
# Get audio_features for  Traditional Country  :  10  Total :  3000
# 318 | 333  Len Tracks for  Traditional Folk :  10
# Get audio_features for  Traditional Folk  :  10  Total :  3010
# 319 | 333  Len Tracks for  Traditional Funk :  10
# Get audio_features for  Traditional Funk  :  10  Total :  3020
# 320 | 333  Len Tracks for  Traditional Irish Fol :  0
# 321 | 333  Len Tracks for  Traditional Reggae :  10
# Get audio_features for  Traditional Reggae  :  10  Total :  3030
# 322 | 333  Len Tracks for  Traditional Rockabilly :  10
# Get audio_features for  Traditional Rockabilly  :  10  Total :  3040
# 323 | 333  Len Tracks for  Traditional Scottish Folk :  10
# Get audio_features for  Traditional Scottish Folk  :  10  Total :  3050
# 324 | 333  Len Tracks for  Traditional Ska :  10
# Get audio_features for  Traditional Ska  :  10  Total :  3060
# 325 | 333  Len Tracks for  Traditional Soul :  10
# Get audio_features for  Traditional Soul  :  10  Total :  3070
# 326 | 333  Len Tracks for  Traditional Swing :  0
# 327 | 333  Len Tracks for  Trance :  10
# Get audio_features for  Trance  :  10  Total :  3080
# 328 | 333  Len Tracks for  Trash Rock :  10
# Get audio_features for  Trash Rock  :  10  Total :  3090
# 329 | 333  Len Tracks for  Tribal House :  10
# Get audio_features for  Tribal House  :  10  Total :  3100
# 330 | 333  Len Tracks for  Trip Hop :  10
# Get audio_features for  Trip Hop  :  10  Total :  3110
# 331 | 333  Len Tracks for  Violin :  10
# Get audio_features for  Violin  :  10  Total :  3120
# 332 | 333  Len Tracks for  Zouk :  10
# Get audio_features for  Zouk  :  10  Total :  3130
# 333 | 333  Len Tracks for  Zydeco :  10
# Get audio_features for  Zydeco  :  10  Total :  3140
#
#
#
# Done

# %% [markdown]
# ## spotify_Exploit

# %%
df = pd.read_csv('audio_features.csv', sep=',')
print(len(df))
df = df.drop_duplicates()
print(len(df))
df.dropna(subset=["item","genre","id","name","artist","danceability","energy","key","mode","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo","duration_ms"], inplace=True)
# Out:
# 154835
# 154835

# %%
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25892\2102218766.py in <module>
# ----> 1 df.head(10)
#
# NameError: name 'df' is not defined

# %%
df['genre_n'] = df['genre'].map(genre_dict)

# %%
df1=df[["id","genre_n","danceability","energy","key","mode","loudness","speechiness","acousticness","instrumentalness","valence","tempo"]]

# %%
scaler = StandardScaler()
X_normalized = scaler.fit_transform(df1[["genre_n","danceability","energy","key","mode","loudness","speechiness","acousticness","instrumentalness","valence","tempo"]])

# %%
df_normalized = pd.DataFrame(X_normalized, columns=["genre_n","danceability","energy","key","mode","loudness","speechiness","acousticness","instrumentalness","valence","tempo"])

# %%
pca = PCA(n_components=11)

# %%
pca.fit(X_normalized)
# Out:
# PCA(n_components=11)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.2685081 , 0.1291794 , 0.10681301, 0.09237195, 0.08636098,
#        0.08063596, 0.07799427, 0.07101061, 0.04538577, 0.02940225,
#        0.0123377 ])

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.2685081 , 0.3976875 , 0.50450051, 0.59687246, 0.68323343,
#        0.76386939, 0.84186366, 0.91287428, 0.95826005, 0.9876623 ,
#        1.        ])

# %%
X_pca = pca.transform(X_normalized)

# %%
kmeans = KMeans(n_clusters=50, n_init=10)

# %%
kmeans.fit(X_pca)
# Out:
# KMeans(n_clusters=50)

# %%
X_pca
# Out:
# array([[ 2.68005897,  3.217465  ,  0.73517353, ...,  0.37572129,
#          0.99935532, -0.47151005],
#        [ 1.14379054,  0.14822082,  1.01290307, ...,  0.35251199,
#         -0.20116232,  0.70333666],
#        [-0.31562679,  0.67992783,  1.72369757, ..., -0.1889641 ,
#          0.20386274,  0.52282222],
#        ...,
#        [-1.86114237, -0.49860683, -0.6232446 , ...,  0.74327241,
#          0.45987599, -0.08618466],
#        [-1.28398808,  1.45134866, -0.92881338, ..., -0.14928217,
#          0.87363308, -0.42829496],
#        [-1.26196361,  1.21040685,  1.38069049, ...,  0.7293487 ,
#          0.93827393, -0.1147942 ]])

# %%
cluster_ids = kmeans.predict(X_pca)

# %%
plt.figure(figsize=(10,10))
for c in np.unique(cluster_ids):
    plt.scatter(X_pca[cluster_ids == c, 0], X_pca[cluster_ids == c, 1], marker='.', s=12)

# %%
#m3d.figure(figsize=(10,10))
fig = plt.figure(figsize = (12, 12))
ax = fig.add_subplot(111, projection='3d')

for c in np.unique(cluster_ids):
    sct = ax.scatter3D(X_pca[cluster_ids == c, 0], X_pca[cluster_ids == c, 1], X_pca[cluster_ids == c, 2], marker='.', s=12)

ax.view_init(-140, 125)

# %%
cluster_ids_fit_pred = KMeans(n_clusters=10, n_init=10).fit_predict(X_normalized)

# %%
plt.figure(figsize=(10,10))
for c in np.unique(cluster_ids_fit_pred):
    plt.scatter(X_normalized[cluster_ids_fit_pred == c, 0], X_normalized[cluster_ids_fit_pred == c, 1], marker='.', s=12)

# %% [markdown]
# # Spotify Playlist Generator

# %%
df["cluster"] = cluster_ids

# %%
df.to_csv('audio_features_clustered_50.csv',',',index=True)

# %%
#Import spotipy Libraries & credentials
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv
import os

load_dotenv('.env')
c_id = os.environ['USER_ID']
c_se = os.environ['USER_Q']

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=c_id, client_secret=c_se))

# %%
my_song_list=["She's a rainbow","Bohemian Rhapsody","Anarchy in the UK"]
SongName = input('Enter song name')
if len(SongName)==0:
    SongName=random.choice(my_song_list)

#get from track name : track id, artist, album
try:
    results = sp.search(q='track:"{}"'.format(SongName), type='track', limit=1)

    #print(results['tracks']['items'][0]['id'])
    album = sp.album(results['tracks']['items'][0]['album']['id'])
    #print(results['tracks']['items'][0]['artists'][0]['id'])
    artist = sp.artist(results['tracks']['items'][0]['artists'][0]['id'])
    #convert genre name to numeric using the dic
    try:
        genre_id = genre_nocap_dict[artist["genres"][0]]
    except:
        genre_id = 289
    print(SongName , ':' , artist['name'] , ',' , album['name'] , '\n' , artist["genres"][0] ,' id:',genre_id )
except spotipy.SpotifyException as e:
    print(e.msg)

iframe = IFrame(src="https://open.spotify.com/embed/track/"+results['tracks']['items'][0]['id']+"?utm_source=generator",
                   width="320",
                   height="80",
                   frameborder="0",
                   allowtransparency="true",
                   allow="encrypted-media"
                  )
display(iframe)

song_audio_features = sp.audio_features(results['tracks']['items'][0]['id'])
MonDic = { 'genre_n' : genre_id,'danceability' : song_audio_features[0]['danceability'],'energy' : song_audio_features[0]['energy'],'key' : song_audio_features[0]['key'],'mode' : song_audio_features[0]['mode'],'loudness' : song_audio_features[0]['loudness'],'speechiness' : song_audio_features[0]['speechiness'],'acousticness' : song_audio_features[0]['acousticness'],'instrumentalness' : song_audio_features[0]['instrumentalness'],'valence' : song_audio_features[0]['valence'],'tempo' : song_audio_features[0]['tempo']}
#print(MonDic)
song_scaled = scaler.transform(pd.DataFrame([MonDic]))
Bin = kmeans.predict(song_scaled)
#print('Cluster:',Bin)
df2=df.loc[df['cluster'] == Bin[0]].sample(n=10)

print('Playlist for',SongName)
display(df2[['genre','name','artist']])
print('cluster',Bin[0])
print(df.loc[df['cluster'] == Bin[0]].value_counts('genre').head(10))

for track_id in df2['id']:
    iframe = IFrame(src="https://open.spotify.com/embed/track/"+track_id+"?utm_source=generator",
                   width="320",
                   height="80",
                   frameborder="0",
                   allowtransparency="true",
                   allow="encrypted-media"
                  )
    display(iframe)
# Out:
# Anarchy in the UK : Sex Pistols , The Sex Pistols
#  alternative rock  id: 257
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/17YNjZoMHOoS8BM1fcgiBk?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Playlist for Anarchy in the UK
#                      genre                                   name  \
# 125264  Psychedelic Trance         High on Mel - No Comment Remix
# 62043           Garage Pop                     Rip Up The Streets
# 129980     Raw Black Metal  The Eternal Melancholy of the Wampyre
# 988             Acid House                  The Dance of Planet X
# 19826         Chill Groove                  Keep On (A Love Tale)
# 12134          Black Metal             Souvenirs d'un autre monde
# 87722           Jazz Metal                 Digital Dream Sequence
# 80931       Indie Shoegaze                  How Fast Can You Love
# 12346          Black Metal                                Песнь 1
# 121105   Progressive Metal                              New Found
#
#                 artist
# 125264          Astrix
# 62043        The Spits
# 129980  Wampyric Rites
# 988        Larry Heard
# 19826    Dave Silovich
# 12134           Alcest
# 87722       Trioscapes
# 80931        Pia Fraus
# 12346          БАТЮШКА
# 121105          Gojira
# cluster 24
# genre
# Raw Black Metal         302
# Black Metal             214
# Garage Pop              192
# Jazz Metal              184
# Indie Shoegaze          123
# Rock Noise               87
# Garage Punk              86
# Progressive Metal        83
# Alternative Hardcore     77
# Space Rock               65
# dtype: int64
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3lyItV83hRQU3WIeGAhTM9?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1bVCDiOtVkcXc4pq58IPbv?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/6TutFIl4YjoaG8pSNKJXna?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1s6H9hlEp3wU2fJUgtZutU?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1BFWvuAIQKzfGn4QqijFjU?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1eD8fNbyfyXWrTLokilmEM?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/2NSBG05S9f94Tm3CHjPxdC?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/0pDWccSLw72zFJX3CVWapE?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/34FWlbZHTtjslQ9u07ghTY?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3Kl4f3sVKb8iwQ8ZffHim6?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

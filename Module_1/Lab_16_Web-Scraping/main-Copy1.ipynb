# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
#import urllib

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://data.oecd.org/fr/energy/energies-renouvelables.htm' 
html = requests.get(url).content
html
# Out:
# b'<!DOCTYPE html>\r\n<html lang="fr">\r\n<head>\r\n<meta charset="utf-8">\r\n<title>\xc3\x89nergie - \xc3\x89nergies renouvelables - OCDE Data</title>\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\r\n<meta name="referrer" content="always">\r\n<meta name="description" content="&lsquo;&Eacute;nergies renouvelables\' d&eacute;signe la part de ces &eacute;nergies dans les approvisionnements totaux en &eacute;nergie primaire." />\n\r\n<meta name="keywords" content="&eacute;nergie; &eacute;nergies renouvelables; primaire; approvisionnement; hydraulique; g&eacute;othermie; solaire; &eacute;olien; mar&eacute;es:vagues; &eacute;nergies des mers; &eacute;nergies mar&eacute;motrice:houlomotrice; biocarburant; bio-essence; biogazole; biogaz; d&eacute;chets; changement climatique; r&eacute;chauffement plan&eacute;taire; combustible fossile; durable; source; &eacute;lectricit&eacute;; puissance;
# ...

# %%
response = requests.get('https://data.oecd.org/fr/energy/energies-renouvelables.htm')
response
# Out:
# <Response [200]>

# %%
# your code here
#url_url = request.get('https://github.com/trending/developers')
#url_url = response

#response = requests.get('https://github.com/trending/developers')
#response.text

soup = BeautifulSoup(html, 'html.parser')
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="fr">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Énergie - Énergies renouvelables - OCDE Data
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="always" name="referrer"/>
#   <meta content="‘Énergies renouvelables' désigne la part de ces énergies dans les approvisionnements totaux en énergie primaire." name="description">
#    <meta content="énergie; énergies renouvelables; primaire; approvisionnement; hydraulique; géothermie; solaire; éolien; marées:vagues; énergies des mers; énergies marémotrice:houlomotrice; biocarburant; bio-essence; biogazole; biogaz; déchets; changement climatique; réchauffement planétaire; combustible fossile; durable; source; électricité; puissance; force" name="keywords">
#     <script type="text/javascript">
# ...

# %%
names_list = []

#for link in soup.find_all('h1',({'class': 'h3 lh-condensed'}):
                          #names_list.append('h1 class="h3')
#print(names_list)

                          
for dev in soup.find_all('h1', {'class': 'h3 lh-condensed'}):
    name = dev.text.strip().replace('\n', '')
    username = dev.find('a')['href'][1:]
    names_list.append(f"{name} (@{username})")

# list of trending developers
names_list
# A revoir
# Out:
# []

# %%
#soup.select("a")[2]["href"]

#for i in soup.find_all('a'):
    #print(link['href'])

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
                          
for dev in soup.find_all('h1', {'class': 'h3 lh-condensed'}):
    name = dev.text.strip().replace('\n', '')
    username = dev.find('a')['href'][1:]
    names_list.append(f"{name} (@{username})")

# list of trending developers
names_list
# A revoir
# Out:
# ['lllyasviel (@lllyasviel)',
#  'Yannic Kilcher (@yk)',
#  'Ariel Mashraki (@a8m)',
#  'Jerry Liu (@jerryjliu)',
#  'Ha Thach (@hathach)',
#  'Charlie Marsh (@charliermarsh)',
#  'shadcn (@shadcn)',
#  'Thomas Camlong (@ajnart)',
#  'Antonio Cheong (@acheong08)',
#  'Matthew Tancik (@tancik)',
#  'leejimqiu (@LeeJim)',
#  'Milan Pavlik (@easyCZ)',
#  'Sandeep Somavarapu (@sandy081)',
#  'van Hauser (@vanhauser-thc)',
#  'Tim Besard (@maleadt)',
#  'Klaus Post (@klauspost)',
#  'Harrison Chase (@hwchase17)',
#  'Bo-Yi Wu (@appleboy)',
#  'Stephen Celis (@stephencelis)',
#  'Ed Page (@epage)',
#  'Sertaç Özercan (@sozercan)',
#  'Kazuhiro Sera (@seratch)',
#  'Gregory Bowne (@gbowne1)',
#  'Artur (@Artur-)',
#  'Manu MA (@manucorporat)',
#  'lllyasviel (@lllyasviel)',
#  'Yannic Kilcher (@yk)',
#  'Ariel Mashraki (@a8m)',
#  'Jerry Liu (@jerryjliu)',
#  'Ha Thach (@hathach)',
#  'Charlie Marsh (@charliermarsh)',
#  'shadcn (@shadcn)',
#  'Thomas Camlong (@ajnart)',
# ...

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url_1 = 'https://data.oecd.org/fr/energy/energies-renouvelables.htm'
html_1 = requests.get(url).content
html_1
# Out:
# b'<!DOCTYPE html>\r\n<html lang="fr">\r\n<head>\r\n<meta charset="utf-8">\r\n<title>\xc3\x89nergie - \xc3\x89nergies renouvelables - OCDE Data</title>\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\r\n<meta name="referrer" content="always">\r\n<meta name="description" content="&lsquo;&Eacute;nergies renouvelables\' d&eacute;signe la part de ces &eacute;nergies dans les approvisionnements totaux en &eacute;nergie primaire." />\n\r\n<meta name="keywords" content="&eacute;nergie; &eacute;nergies renouvelables; primaire; approvisionnement; hydraulique; g&eacute;othermie; solaire; &eacute;olien; mar&eacute;es:vagues; &eacute;nergies des mers; &eacute;nergies mar&eacute;motrice:houlomotrice; biocarburant; bio-essence; biogazole; biogaz; d&eacute;chets; changement climatique; r&eacute;chauffement plan&eacute;taire; combustible fossile; durable; source; &eacute;lectricit&eacute;; puissance;
# ...

# %%
# your code here
#response = requests.get('https://github.com/trending/developers')
#response

# alternative test

url = 'https://data.oecd.org/fr/energy/energies-renouvelables.htm'

response = requests.get(url).content
sp = BeautifulSoup(response,'html.parser')

selector = '#indicator-chart > div.ddp-chart.indicator-main-chart.normal.compact-header > div.html-chart.ddp-chart-inner.multiple-table > div.multiple-table-scroll-wrapper > div.multiple-table-tables > div > div > table > tbody > tr:nth-child(1)'

# %%
sp.select(selector)[0:].get_text()
#repo_names.append(('text.replace('\n','').split('/')[1].strip()'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fp/nkvz8km55ybd4yzr2wcb2pjr0000gn/T/ipykernel_85747/2084565963.py in <module>
# ----> 1 sp.select(selector)[0:].get_text()
#       2 #repo_names.append(('text.replace('\n','').split('/')[1].strip()'))
#
# NameError: name 'sp' is not defined

# %%
#soup = BeautifulSoup(html_1, 'html.parser')
#soup
#print(soup.prettify())

selector_0 = 'table > tbody > tr:nth-child(1)'
len(sp.select(selector_0))
# Out:
# 0

# %%
list_repo_names = []

for link in sp.select(selector_0):
    print(link.get_text())
    list_repo_names.append(link.get_text())
    
list_repo_names
a = list_repo_names.text.replace('text.replace('\n','').split('/')[1].strip()')
a
# Out:
#   File "/var/folders/fp/nkvz8km55ybd4yzr2wcb2pjr0000gn/T/ipykernel_32932/1389467480.py", line 8
#     a = list_repo_names.text.replace('text.replace('\n','').split('/')[1].strip()')
#                                                      ^
# SyntaxError: unexpected character after line continuation character

# %%
repo_names = pd.DataFrame({'repo-names':list_repo_names})
repo_names
# Out:
#                                   repo-names
# 0    \n\n\n\n      ControlNet-v1-1-nightly\n
# 1           \n\n\n\n      gpt-4chan-public\n
# 2         \n\n\n\n      golang-cheat-sheet\n
# 3                \n\n\n\n      llama_index\n
# 4                    \n\n\n\n      tinyusb\n
# 5                       \n\n\n\n      ruff\n
# 6                   \n\n\n\n      taxonomy\n
# 7                     \n\n\n\n      homarr\n
# 8                    \n\n\n\n      ChatGPT\n
# 9   \n\n\n\n      fourier-feature-networks\n
# 10    \n\n\n\n      HowToCookOnMiniprogram\n
# 11          \n\n\n\n      vscode-todotasks\n
# 12                 \n\n\n\n      thc-hydra\n
# 13                   \n\n\n\n      LLVM.jl\n
# 14                  \n\n\n\n      compress\n
# 15                 \n\n\n\n      langchain\n
# 16                   \n\n\n\n      CodeGPT\n
# 17              \n\n\n\n      SQLite.swift\n
# 18          \n\n\n\n      cargo-script-mvs\n
# 19                \n\n\n\n      kubectl-ai\n
# ...

# %%
names_list_1 = []

#for link in soup.find_all('h1',({'class': 'h3 lh-condensed'}):
                          #names_list.append('h1 class="h3')
#print(names_list)

                          
for dev in soup.find_all('h1', {'class': 'h3 lh-condensed'}):
    name = dev.text.strip().replace('\n', '')
    username = dev.find('a')['href'][1:]
    names_list_1.append(f"{name} (@{username})")

# list of trending developers
names_list_1
# A revoir
# Out:
# []

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
# your code here

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here

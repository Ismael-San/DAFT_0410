# %%
import json
import requests

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

# %%
SITE
# Out:
# <Stack Overflow> v:<2.2> endpoint: comments  Last URL: https://api.stackexchange.com/2.2/comments/?pagesize=100&page=5&filter=default&site=stackoverflow

# %%
comments = SITE.fetch('comments')
comments
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 163,
#  'total': 0,
#  'items': [{'owner': {'reputation': 93,
#     'user_id': 4271921,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0ae9911ff2105128cfb273d36eebf87e?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Chris_F',
#     'link': 'https://stackoverflow.com/users/4271921/chris-f'},
#    'reply_to_user': {'reputation': 9141,
#     'user_id': 2602877,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c76ea7b35660e77624550130276c61d3?s=256&d=identicon&r=PG',
#     'display_name': 'Christoph Rackwitz',
#     'link': 'https://stackoverflow.com/users/2602877/christoph-rackwitz'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1681904855,
#    'post_id': 76048746,
#    'comment_id': 134131442,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 86477,
# ...

# %%
comments_questions = SITE.fetch('questions', fromdate=1638877910, todate=1638877910, min=5, tagged='python', sort='votes') 
comments_questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 125,
#  'total': 0,
#  'items': []}

# %%
comments_awnsers = SITE.fetch('awnsers', fromdate=1638877910, todate=1638877910, min=5, tagged='python', sort='votes')
comments_awnsers
# Out:
# ---------------------------------------------------------------------------
# StackAPIError                             Traceback (most recent call last)
# /var/folders/fp/nkvz8km55ybd4yzr2wcb2pjr0000gn/T/ipykernel_4512/1080783751.py in <module>
# ----> 1 comments_awnsers = SITE.fetch('awnsers', fromdate=1638877910, todate=1638877910, min=5, tagged='python', sort='votes')
#       2 comments_awnsers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/stackapi/stackapi.py in fetch(self, endpoint, page, key, filter, **kwargs)
#     210                 code = response["error_name"]
#     211                 message = response["error_message"]
# --> 212                 raise StackAPIError(self._previous_call, error, code, message)
#     213             except KeyError:
#     214                 pass  # This means there is no error
#
# ...

# %%
#response = requests.get('https://api.stackexchange.com/2.2/comments/?pagesize=100&page=5&filter=default&site=stackoverflow')
#results = response.json()
#results
# Out:
# {'items': [{'owner': {'reputation': 126,
#     'user_id': 4141763,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-rcnbyQEZGvo/AAAAAAAAAAI/AAAAAAAAAGE/PsN_R-MR04E/photo.jpg?sz=256',
#     'display_name': 'Ahmed Nabil',
#     'link': 'https://stackoverflow.com/users/4141763/ahmed-nabil'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1681901487,
#    'post_id': 45141395,
#    'comment_id': 134130686,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 26766,
#     'user_id': 3978545,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/jmQsw.png?s=256&g=1',
#     'display_name': 'Wolfie',
#     'link': 'https://stackoverflow.com/users/3978545/wolfie'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1681901484,
#    'post_id': 76053355,
#    'comment_id': 134130685,
#    'content_license': 'CC BY-SA 4.0'},
# ...

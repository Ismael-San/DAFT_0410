# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2023-03-30
# 3     Worldwide Governance Indicators                                       WGI              3  2022-09-23
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-12-06
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
wb.economy.info()
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       UMC
# ...

# %%
wb.series.info()
# Out:
# id                         value
# -------------------------  --------------------------------------------------------------------------------------------------------------------------------------------
# AG.AGR.TRAC.NO             Agricultural machinery, tractors
# AG.CON.FERT.PT.ZS          Fertilizer consumption (% of fertilizer production)
# AG.CON.FERT.ZS             Fertilizer consumption (kilograms per hectare of arable land)
# AG.LND.AGRI.K2             Agricultural land (sq. km)
# AG.LND.AGRI.ZS             Agricultural land (% of land area)
# AG.LND.ARBL.HA             Arable land (hectares)
# AG.LND.ARBL.HA.PC          Arable land (hectares per person)
# AG.LND.ARBL.ZS             Arable land (% of land area)
# AG.LND.CREL.HA             Land under cereal production (hectares)
# AG.LND.CROP.ZS             Permanent cropland (% of land area)
# AG.LND.EL5M.RU.K2          Rural land area where elevation is below 5 meters (sq. km)
# ...

# %%
wb.series.info(q="gender")
#filter data by using a word
# Out:
# id                 value
# -----------------  ---------------------------------------------------
# IS.RRS.GOOD.MT.K6  Railways, goods transported (million ton-km)
# IS.RRS.PASG.KM     Railways, passengers carried (million passenger-km)
#                    2 elements

# %%
#business = wb.data.DataFrame('IC.REG.DURS', ['USA','CHN','FRA'])
business = wb.data.DataFrame('IC.REG.DURS',['FRA','UKR','EST','XKX','SWE'],time=range(2015,2019))
business
#['FRA','UKR','EST','XKX','SWE']
#wb.region.members('ECS')
# Out:
#          YR2015  YR2016  YR2017  YR2018
# economy
# EST         3.5     3.5     3.5     3.5
# FRA         4.0     3.5     3.5     3.5
# SWE         7.0     7.0     7.0     7.5
# UKR         8.0     6.5     6.5     6.5
# XKX        10.0     6.0     5.5     5.5

# %%
ren = wb.data.DataFrame('IC.REG.DURS', ['FRA','UKR','EST','XKX','SWE'], time=range(2015,2019))
ren
# Out:
#          YR2015  YR2016  YR2017  YR2018
# economy
# EST         3.5     3.5     3.5     3.5
# FRA         4.0     3.5     3.5     3.5
# SWE         7.0     7.0     7.0     7.5
# UKR         8.0     6.5     6.5     6.5
# XKX        10.0     6.0     5.5     5.5

# %%
ren.plot.bar()
#display plot.bar
# Out:
# <AxesSubplot:xlabel='economy'>

# %%
wb.data.DataFrame('IC.REG.DURS', ['FRA','UKR','EST','XKX','SWE'], time=range(2015,2019,3)).T.plot();

# %%
g5 = business.sort_values(by=['YR2019'],ascending=True)[:10]
g5
#to sort value
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# GEO         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# UZB         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AZE         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NLD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# EST         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# DNK         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ARM         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NOR         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# MDA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# GRC         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy                  ...
# ...

# %%
ax = business.T.plot(color='blue', legend=False)
ax
# Out:
# <AxesSubplot:>

# %%
g5.T.plot(ax=ax, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
a = g5.T.plot(ax=ax, figsize=(15,5))
a
# Out:
# <AxesSubplot:>
